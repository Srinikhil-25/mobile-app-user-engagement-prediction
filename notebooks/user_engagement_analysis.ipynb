# %% [markdown]
# # Mobile App User Engagement Prediction
#
# Reproducible project notebook for the Business Analytics mini-project.

# %%
from pathlib import Path
from src.pipeline import Config, run
ROOT = Path.cwd()
run(Config(
    data_path=ROOT/'data'/'mobile_app_interactions.csv',
    results_dir=ROOT/'results',
    figures_dir=ROOT/'figures'/'model_evaluation'
))

# %%
import pandas as pd
pd.read_csv('results/model_comparison.csv')

# %% [markdown]
# The generated files in `results/` and `figures/model_evaluation/` contain the model metrics and evaluation visuals.
